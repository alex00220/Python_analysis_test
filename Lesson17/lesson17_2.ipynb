# %%
import numpy as np
import pandas as pd
string_data = pd.Series(['板橋區', '中和區', np.nan, '土城區'])
string_data

# %%
string_data[0] = np.nan
string_data

# %% [markdown]
# isnull()
# notnull()
# fillna()
# dropna()

# %%
#給人類檢查用#
string_data.info()

# %%
string_data.isnull()

# %%
masked = string_data.notnull()
string_data[masked]

# %%
string_data.fillna("不知道")

# %%
string_data.dropna()

# %% [markdown]
# 如何資料轉換型別
# astype()

# %%
data = pd.Series(["1.", "-999.", "2.", "-999.", "-1000.", "3."])
data.astype(float)

# %% [markdown]
# replace
# data = pd.Series(["1.", "-999.", "2.", "-999.", "-1000.", "3.."]) data.replace("3..","3.")

# %%
data = pd.Series(["1.", "-999.", "2.", "-999.", "-1000.", "3.."])
data.replace("3..","3.")

# %% [markdown]
# 使用apply(),使用自訂的function

# %%
def clear_data(x):
    try:
        value = float(x)
        return value
    except:
        return 0
    

data = pd.Series(["1.", "-999.", "2.", "-999.", "-1000.", "3.."])
data.apply(clear_data)
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       0.0
# dtype: float64
