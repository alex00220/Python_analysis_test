# %%
import pandas as pd
import tools as ts
from tools import Student

print(ts.PI)
print(ts.func1(10, 20))
stu1 = Student("robert", 89, 95, 65)
print(stu1.name)
print(stu1.chinese)
print(stu1.math)
print(stu1.english)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import tools as ts
#       3 from tools import Student
#       5 print(ts.PI)
#
# ModuleNotFoundError: No module named 'tools'
