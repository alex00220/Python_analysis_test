# %% [markdown]
# python如何讀取students.csv
# 你可以使用 Python 內建的 csv 模組來讀取 students.csv，以下是簡單的範例：
#
# import csv
#
# with open('students.csv', newline='', encoding='utf-8') as csvfile:
#     reader = csv.DictReader(csvfile)  # 使用 DictReader 讀取成字典格式
#     for row in reader:
#         print(row)  # 每一列會是字典，鍵是欄位名稱
# 說明：
#
# open() 中指定 encoding='utf-8' 避免中文亂碼。
# csv.DictReader 會自動把 CSV 第一列當作欄位名稱，並將每列轉成字典。
# 你也可以用 csv.reader 讀成串列形式，但 DictReader 更適合有欄位標題的 CSV。
# 執行後，每一列會輸出類似：
#
# {'姓名': '錢欣潔', '國文': '100', '英文': '77', '數學': '59'}
# {'姓名': '許芳如', '國文': '98', '英文': '74', '數學': '99'}
# {'姓名': '陳怡伶', '國文': '54', '英文': '67', '數學': '79'}
# 這是讀取 CSV 檔案並取得每筆資料的標準作法[1][2][4][5]。

# %%
import csv
from csv import DictReader

with open('students.csv',encoding='utf-8',newline='') as csv_file:
    reader:DictReader = csv.DictReader(csv_file)
    students = list(reader)
    
students
# Out:
# [{'姓名': '林志喜', '國文': '61', '英文': '62', '數學': '73'},
#  {'姓名': '黃雅慧', '國文': '51', '英文': '90', '數學': '69'},
#  {'姓名': '林柏洋', '國文': '100', '英文': '53', '數學': '89'},
#  {'姓名': '黃柏宇', '國文': '94', '英文': '67', '數學': '81'},
#  {'姓名': '賴佳雯', '國文': '99', '英文': '64', '數學': '95'},
#  {'姓名': '陳筱涵', '國文': '81', '英文': '72', '數學': '62'},
#  {'姓名': '余宗儒', '國文': '65', '英文': '70', '數學': '76'},
#  {'姓名': '楊少亮', '國文': '73', '英文': '81', '數學': '99'},
#  {'姓名': '柯宜臻', '國文': '59', '英文': '80', '數學': '99'},
#  {'姓名': '張俊傑', '國文': '76', '英文': '57', '數學': '75'},
#  {'姓名': '沈心利', '國文': '93', '英文': '59', '數學': '69'},
#  {'姓名': '王雅琴', '國文': '64', '英文': '100', '數學': '90'},
#  {'姓名': '孫火清', '國文': '98', '英文': '65', '數學': '74'},
#  {'姓名': '張牧聿', '國文': '73', '英文': '93', '數學': '65'},
#  {'姓名': '鄧淑娟', '國文': '78', '英文': '97', '數學': '73'},
#  {'姓名': '陳信宏', '國文': '54', '英文': '85', '數學': '56'},
#  {'姓名': '謝南慧', '國文': '84', '英文': '69', '數學': '60'},
#  {'姓名': '李美洋', '國文': '89', '英文': '54', '數學': '52'},
#  {'姓名': '馮耀中', '國文': '80', '英文': '74', '數學': '81'},
#  {'姓名': '盧文啟', '國文': '58', '英文': '87', '數學': '76'},
#  {'姓名': '吳昕婷', '國文': '65', '英文': '60', '數學': '91'},
#  {'姓名': '蔡世馨', '國文': '68', '英文': '62', '數學': '59'},
#  {'姓名': '胡淑貞', '國文': '80', '英文': '95', '數學': '79'},
#  {'姓名': '陳建香', '國文': '80', '英文': '77', '數學': '100'},
#  {'姓名': '鍾俞禎', '國文': '96', '英文': '58', '數學': '53'},
#  {'姓名': '劉昀天', '國文': '55', '英文': '82', '數學': '87'},
#  {'姓名': '溫法堯', '國文': '75', '英文': '82', '數學': '81'},
#  {'姓名': '張嘉韋', '國文': '67', '英文': '97', '數學': '59'},
#  {'姓名': '黃彥孝', '國文': '85', '英文': '75', '數學': '83'},
#  {'姓名': '劉林中', '國文': '54', '英文': '91', '數學': '69'},
#  {'姓名': '王梅劭', '國文': '78', '英文': '68', '數學': '86'},
#  {'姓名': '劉嘉泰', '國文': '56', '英文': '94', '數學': '57'},
#  {'姓名': '葉祖雄', '國文': '59', '英文': '57', '數學': '56'},
#  {'姓名': '黃善迪', '國文': '63', '英文': '96', '數學': '69'},
#  {'姓名': '洪奎夫', '國文': '68', '英文': '99', '數學': '51'},
#  {'姓名': '朱惠儀', '國文': '97', '英文': '65', '數學': '63'},
#  {'姓名': '林佳人', '國文': '67', '英文': '62', '數學': '56'},
#  {'姓名': '景歡燦', '國文': '70', '英文': '59', '數學': '82'},
#  {'姓名': '王士銘', '國文': '62', '英文': '84', '數學': '53'},
#  {'姓名': '吳麗卿', '國文': '73', '英文': '55', '數學': '75'},
#  {'姓名': '陳淑娟', '國文': '92', '英文': '58', '數學': '98'},
#  {'姓名': '林玉佩', '國文': '85', '英文': '88', '數學': '99'},
#  {'姓名': '陳怡伶', '國文': '79', '英文': '69', '數學': '85'},
#  {'姓名': '王人仰', '國文': '91', '英文': '53', '數學': '94'},
#  {'姓名': '李政成', '國文': '78', '英文': '55', '數學': '64'},
#  {'姓名': '羅幸娥', '國文': '87', '英文': '57', '數學': '79'},
#  {'姓名': '郭舜昇', '國文': '53', '英文': '76', '數學': '99'},
#  {'姓名': '李進慧', '國文': '75', '英文': '58', '數學': '77'},
#  {'姓名': '柯韋成', '國文': '73', '英文': '56', '數學': '66'},
#  {'姓名': '周怡啟', '國文': '83', '英文': '89', '數學': '92'}]
