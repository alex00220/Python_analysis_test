# %%
import requests
from requests import Response

url:str = 'https://data.ntpc.gov.tw/api/datasets/1e548c60-0b04-4507-bf60-f3be651db642/csv?page=0&size=100'
response:Response = requests.get(url, timeout=5)
if response.status_code == 200:
    print("下載成功")
else:
    print("下載失敗")
# Out:
# 下載成功

# %% [markdown]
# 好的，以下是使用繁體中文的說明：
#
# 在 Python 中，如果你想要從一個字串（str）建立一個類似檔案的物件，可以使用 io 模組裡的 StringIO 類別。它會建立一個「記憶體中的檔案物件」，這個物件可以像一般檔案一樣進行讀取、寫入和定位（seek）操作。
#
# 範例程式碼如下：
#
# import io
#
# # 用字串建立一個檔案物件
# file_obj = io.StringIO("這是一段初始文字")
#
# # 讀取內容
# print(file_obj.read())  # 輸出：這是一段初始文字
#
# # 將檔案指標移回開頭
# file_obj.seek(0)
#
# # 寫入更多文字
# file_obj.write("，這是後面新增的文字")
#
# # 再次移回開頭，讀取整個內容
# file_obj.seek(0)
# print(file_obj.read())  # 輸出：這是一段初始文字，這是後面新增的文字
# 重點說明
# io.StringIO 是用來處理文字（str）的檔案物件。
# 如果是二進位資料（bytes），可以用 io.BytesIO。
# 這種方式不會在硬碟建立實體檔案，而是在記憶體中模擬檔案行為。
# 適合用在需要傳入檔案物件，但資料本身已經是字串的情況。
# 你已經有一個 CSV 格式的字串轉成的檔案物件（file-like object），想要將它轉成「list 裡面包含 dict」的格式，可以使用 Python 內建的 csv.DictReader 來達成。
#
# 以下是示範程式碼：
#
# import io
# import csv
#
# # 假設你已經有一個 CSV 格式的字串
# csv_string = """Name,Job,Age,Income
# Alice,Programmer,23,110000
# Bob,Executive,34,90000
# Carl,Sales,45,50000
# """
#
# # 將字串轉成檔案物件
# file_obj = io.StringIO(csv_string)
#
# # 使用 csv.DictReader 讀取檔案物件
# reader = csv.DictReader(file_obj)
#
# # 將讀取結果轉成 list 裡面包含 dict
# list_of_dicts = list(reader)
#
# # 印出結果
# print(list_of_dicts)
# 輸出結果會是：
#
# [
#   {'Name': 'Alice', 'Job': 'Programmer', 'Age': '23', 'Income': '110000'},
#   {'Name': 'Bob', 'Job': 'Executive', 'Age': '34', 'Income': '90000'},
#   {'Name': 'Carl', 'Job': 'Sales', 'Age': '45', 'Income': '50000'}
# ]
# 說明：
#
# csv.DictReader 會自動將 CSV 第一行當作欄位名稱（key），後面的每一行資料轉成對應的字典（value）。
# list() 將 DictReader 物件轉成清單，方便後續使用。
# 這種方式適用於你已經有一個類似檔案的物件（例如 io.StringIO 建立的物件）[1][2][5][6]。

# %%
from pprint import pprint
import io
import csv
#print(type(response.text))
newText = response.text.replace('\ufeff','')
#print(newText)
file = io.StringIO(newText)
reader = csv.DictReader(file)
parking:list = list(reader)
parking
# Out:
# [{'zone': '八里區',
#   'areacode': '65000230',
#   'address': '觀海大道',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '八里區',
#   'areacode': '65000230',
#   'address': '13行博物館第二停車場',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '八里區',
#   'areacode': '65000230',
#   'address': '13行博物館第二停車場',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '八里區',
#   'areacode': '65000230',
#   'address': '八里區賢二街10-1號前',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '不收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '八里區',
#   'areacode': '65000230',
#   'address': '八里區中山路323巷(第一停車場旁)',
#   'quantity': '1',
#   'vehicle_classification': '機車',
#   'charged': '不收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '重陽路1段134號對面(13格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '重陽路1段134號對面(14格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '重陽路與力行路口(75格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '重陽路4段99號(土地銀行)(101號格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '重陽路3段5巷大同公園旁（210格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '成功路21號(洽公專用)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '集成路50號前（19格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '集美街1號（01格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '集美街57號對面（139格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '集美街210號之5號前（98格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '集美街63號對面（131格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '新興路50號（03格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '新北大道1段17號（3格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '新北大道1段9號（30格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '過圳街42號（15格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '過圳街7巷22號對面（46格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '過圳街7巷28號對面（49格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '過圳街平面停車場(52格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '過圳公園旁（09格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '中正南路253號（34格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '中正北路111號三重果菜公司前（48格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '中正北路三重商工前（119格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '中正北路592號（162格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '中正北路320號（192格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '中正北路10號（255格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '中正北路綜合運動場前（258格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '中正北路25巷（288格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '重新路3段115巷(14格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '中正南路（22格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三信路三重高中前(10格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三信路三重高中前(11格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三賢街(格位號：51格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三賢街(格位號：91格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區集英路(格位號：28格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區環河北路三段(格位號：8格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區自強路1段101號(18格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區自強路３段103號對面（107格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區自強路３段103號對面（108格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區自強路１段158號（178格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區自強路１段158號（179格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三和路2段30號（53格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三和路192號宏仁醫院前（52格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三和路格致中學前（25格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三和路172號（44格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '否',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三和路三重國小捷運前（6格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三和路三段79號前（9格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三信路三重高中前(12格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三信路三重高中前(13格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三賢街(格位號：131格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區三賢街(格位號：171格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區集英路(格位號：29格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區環河北路三段(格位號：9格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區自強路1段101號(19格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區自強路３段103號對面（109格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區高速公路平面道路（01格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區高速公路平面道路（70格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區高速公路平面道路（181格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區高速公路平面道路（362格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區高速公路平面道路（272格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區高速公路平面道路（220格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區高速公路平面道路（559格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '否',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區永福街(力行路2段162巷55號)（44格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區永福街119號對面(永福國小旁)（49格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區力行路2段德心診所（18格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區福隆路（08格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重區五華街160號碧華國小前（16格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重集賢（01格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '否',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '三重集賢（64格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '否',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '正義北路201號（40格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '正義北路303號（57格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '正義北路299號（55格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '正義北路220號前（102格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '正義北路100號（110格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '正義北路183號（36格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '正義南路62號前（26格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '正義南路62號前（27格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '正義南路17號（57格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '光復路2段171號（100格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '光復路1段136號（146格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '光復路1段72號（158格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '興德路100號（60格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '重光街（34格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '忠孝路1段35號（04格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '忠孝路1段101號（17格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '忠孝路三段三重商工旁（80格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '忠孝路3段89號二重國中對面（118格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '忠孝路2段74號（150格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '忠孝路2段與自強路口（177格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '忠孝路1段50號（221格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '忠孝路1段6之1號郵局前（229格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '忠孝路228公園旁（255格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '忠孝路3段89號二重國中旁（273格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '中興北街175巷（20格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '重新橋下平面停車場(36格)',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'},
#  {'zone': '三重區',
#   'areacode': '65000020',
#   'address': '疏洪東路（207格）',
#   'quantity': '1',
#   'vehicle_classification': '汽車',
#   'charged': '收費',
#   'disabled_parking_sign': '是',
#   'disabled_parking_lot': '是'}]
