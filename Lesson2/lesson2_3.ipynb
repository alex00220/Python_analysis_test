# %%
print("Hello!Test myself")
# Out:
# Hello!Test myself

# %%
n1 = 56 * 72
n1
# Out:
# 4032

# %%
width = 45.87
height = 92.57
area = width * height
print(f"矩形的寬是:{width},高是:{height},面積是:{area}")
# Out:
# 矩形的寬是:45.87,高是:92.57,面積是:4246.1858999999995
