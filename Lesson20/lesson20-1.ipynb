# %% [markdown]
# https://www.perplexity.ai/search/94f7fc8c-0595-416f-b080-1e318bd7404d

# %%
import numpy as np
import pandas as pd

data = pd.Series(np.random.randn(9),
                index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
                       [1, 2, 3, 1, 2, 3, 1, 2, 3]])
data

# %%
data['a']
# Out:
# 1   -0.132421
# 2   -0.166432
# 3    0.115798
# dtype: float64

# %%
data['a'][2]
# Out:
# np.float64(-0.16643227497141214)

# %%
data['a':'b']
# Out:
# a  1   -0.132421
#    2   -0.166432
#    3    0.115798
# b  1   -0.641561
#    2   -0.015168
# dtype: float64

# %%
#Series->堆疊資料>(long data)
#2維資料->非堆疊資料>(width data)
data.unstack().stack()
# Out:
# a  1   -0.132421
#    2   -0.166432
#    3    0.115798
# b  1   -0.641561
#    2   -0.015168
# c  1    0.346187
#    3    0.406910
# d  2    1.056734
#    3    0.242503
# dtype: float64
